# %% [markdown]
# # GUJARAT UNIVERSITY

# %% [markdown]
# # MSC IT-DATA MANAGEMENT & VISUAL INSIGHTS(5 YEARS INTEGRATED)

# %% [markdown]
# # TERM END EXAMINATIONS

# %% [markdown]
# # SEMESTER 5

# %% [markdown]
# ### SUBJECT NAME: DATA ANALYTICS PROGRAMMING LANGUAGE

# %% [markdown]
# **TIME: 3HRS**
#
# **MAX MARKS: 70**
#
# **CODE:DMVIBSC25**

# %% [markdown]
# **Important Note:**
#  - Q1 & Q2 are compulsory and you can attempt any two questions from Q3, Q4 & Q5.
#  - Write clearly and concisely.
#  - File name should be "FullEnrollMentNo_StundentName_DAPL_SEM5_DATA"
#  - Import required Libraries

# %% [markdown]
# ### 1.	Explain the concepts of DataFrame and Series in the context of the pandas library in Python. Provide examples of how these data structures are used for data manipulation also craete the dataframe ith 5 columns "name","marks", "City","country","grade" add the 30 obesrvations in it. (30 marks)

# %% [markdown]
# #### Data Frame
# - Whenever there is a scenario that compliesis multiple attributes at a time the data structure we follow is called Data Frame.¶
# - Most probably when we have two dimensional data that data strucuture is nothing but the dataframe

# %% [markdown]
# **Series**
# - Series are the formated values having indexing

# %%
import pandas as pd

# %%
series1 = pd.Series(['Name1','Name2','Name3','Name4','Name5','Name6','Name7','Name8','Name9','Name10','Name11','Name12','Name13','Name14','Name15','Name16','Name17','Name18','Name19','Name20','Name21','Name22','Name23','Name24','Name25','Name26','Name27','Name28','Name29','Name30'])
series2 = pd.Series([25, 30, 22, 40, 18, 25, 30, 22, 40, 18, 25, 30, 22, 40, 18, 25, 30, 22, 40, 18, 25, 30, 22, 40, 18, 25, 30, 22, 40, 18])
series3 = pd.Series(['New York', 'San Francisco', 'Seattle', 'California', 'Queens', 'New York', 'San Francisco', 'Seattle', 'California', 'Queens', 'New York', 'San Francisco', 'Seattle', 'California', 'Queens', 'New York', 'San Francisco', 'Seattle', 'California', 'Queens', 'New York', 'San Francisco', 'Seattle', 'California', 'Queens', 'New York', 'San Francisco', 'Seattle', 'California', 'Queens'])
series4 = pd.Series(['India','Canada','France','Russia','America','India','Canada','France','Russia','America','India','Canada','France','Russia','America','India','Canada','France','Russia','America', 'India','Canada','France','Russia','America', 'India','Canada','France','Russia','America'])
series5 = pd.Series(['A','B','C','D','E','A','B','C','D','E','A','B','C','D','E','A','B','C','D','E','A','B','C','D','E','A','B','C','D','E'])

# %%
# Create a DataFrame using the Series objects
DataFrame = pd.DataFrame({
    "Name": series1,
    "Marks": series2,
    "City": series3,
    "Country": series4,
    "Grade": series5,
})

DataFrame
# Out:
#       Name  Marks           City  Country Grade
# 0    Name1     25       New York    India     A
# 1    Name2     30  San Francisco   Canada     B
# 2    Name3     22        Seattle   France     C
# 3    Name4     40     California   Russia     D
# 4    Name5     18         Queens  America     E
# 5    Name6     25       New York    India     A
# 6    Name7     30  San Francisco   Canada     B
# 7    Name8     22        Seattle   France     C
# 8    Name9     40     California   Russia     D
# 9   Name10     18         Queens  America     E
# 10  Name11     25       New York    India     A
# 11  Name12     30  San Francisco   Canada     B
# 12  Name13     22        Seattle   France     C
# 13  Name14     40     California   Russia     D
# 14  Name15     18         Queens  America     E
# 15  Name16     25       New York    India     A
# 16  Name17     30  San Francisco   Canada     B
# 17  Name18     22        Seattle   France     C
# 18  Name19     40     California   Russia     D
# ...

# %% [markdown]
# ### 2.	Perform the Univariate Analysis on given dataset,Use appropriate visualizations to explore relationships between variables and draw meaningful conclusions.(DATA1.CSV)(20 Marks)

# %%
# CODE HERE

# %%
# Import the NumPy library for numerical operations
import numpy as np

# Import the Pandas library for data manipulation and analysis
import pandas as pd

# Import the Seaborn library for data visualization
import seaborn as sns

# Import the Matplotlib library for creating static, animated, or interactive visualizations
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('DATA1.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
# Display the information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
# Display the shape of the data
df.shape
# Out:
# (550068, 12)

# %%
# Display the columns of the data
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
# Display the count, mean, std, minimum, Q1, Q2, Q3, and maximum
df.describe().T
# Out:
#                        count          mean          std        min        25%  \
# User_ID             550068.0  1.003029e+06  1727.591586  1000001.0  1001516.0
# Occupation          550068.0  8.076707e+00     6.522660        0.0        2.0
# Marital_Status      550068.0  4.096530e-01     0.491770        0.0        0.0
# Product_Category_1  550068.0  5.404270e+00     3.936211        1.0        1.0
# Product_Category_2  376430.0  9.842329e+00     5.086590        2.0        5.0
# Product_Category_3  166821.0  1.266824e+01     4.125338        3.0        9.0
# Purchase            550068.0  9.263969e+03  5023.065394       12.0     5823.0
#
#                           50%        75%        max
# User_ID             1003077.0  1004478.0  1006040.0
# Occupation                7.0       14.0       20.0
# Marital_Status            0.0        1.0        1.0
# Product_Category_1        5.0        8.0       20.0
# Product_Category_2        9.0       15.0       18.0
# ...

# %%
# Display the histograms of all the numerical data in the dataset
df.hist(figsize=(12, 10))
plt.suptitle('Histograms for Numerical Columns', y=1.02, fontsize=16)
plt.show()

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Gender', data=df, order=df['Gender'].value_counts().index)
plt.title('Distribution of Gender')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Inference**
# - There are more Males in the dataset
# - There are less Females in the dataset

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Age', data=df, order=df['Age'].value_counts().index)
plt.title('Distribution of Age')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Inference**
# - Age group of 26-35 are more present
# - Age group of 0-17 are the least

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Occupation', data=df, order=df['Occupation'].value_counts().index)
plt.title('Distribution of Occupation')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Inference**
# - Occupation of 4 are more present
# - Occupation of 8 are the least

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='City_Category', data=df, order=df['City_Category'].value_counts().index)
plt.title('Distribution of City_Category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Inference**
# - City Category of B are more present
# - City Category of A are the least

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Stay_In_Current_City_Years', data=df, order=df['Stay_In_Current_City_Years'].value_counts().index)
plt.title('Distribution of Stay_In_Current_City_Years')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Inference**
# - There are peoples who are living in the same city most of 1
# - There are peoples who are living in the same city least of 0

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Marital_Status', data=df, order=df['Marital_Status'].value_counts().index)
plt.title('Distribution of Marital_Status')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Inference**
# - Unmarried people are most in the dataset
# - Married people are least in the dataset

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Product_Category_1', data=df, order=df['Product_Category_1'].value_counts().index)
plt.title('Distribution of Product_Category_1')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Inference**
# - In Product_Category_1 :- Category 5 has the most counts
# - In Product_Category_1 :- Category 9 has the least counts

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Product_Category_2', data=df, order=df['Product_Category_2'].value_counts().index)
plt.title('Distribution of Product_Category_2')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Inference**
# - In Product_Category_2 :- Category 8.0 has the most counts
# - In Product_Category_2 :- Category 7.0 has the least counts

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Product_Category_3', data=df, order=df['Product_Category_3'].value_counts().index)
plt.title('Distribution of Product_Category_3')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Inference**
# - In Product_Category_3 :- Category 16.0 has the most counts
# - In Product_Category_3 :- Category 3.0 has the least counts

# %% [markdown]
# ### 3.	Perform the Bivariate Analysis on Given dataset,Use appropriate visualizations to explore relationships between variables and draw meaningful conclusions.(DATA2.CSV)(10 Marks)

# %%
# Import the NumPy library for numerical operations
import numpy as np

# Import the Pandas library for data manipulation and analysis
import pandas as pd

# Import the Seaborn library for data visualization
import seaborn as sns

# Import the Matplotlib library for creating static, animated, or interactive visualizations
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('DATA2.csv')

# %%
df.head()
# Out:
#    price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 0   24.0       32.31     0.538     6.575  65.2   4.35   3.81   4.18   4.01
# 1   21.6       37.07     0.469     6.421  78.9   4.99   4.70   5.12   5.06
# 2   34.7       37.07     0.469     7.185  61.1   5.03   4.86   5.01   4.97
# 3   33.4       32.18     0.458     6.998  45.8   6.21   5.93   6.16   5.96
# 4   36.2       32.18     0.458     7.147  54.2   6.16   5.86   6.37   5.86
#
#    teachers  poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall  \
# 0      24.7       4.98     YES       5.480      11.1920     River        23
# 1      22.2       9.14      NO       7.332      12.1728      Lake        42
# 2      22.2       4.03      NO       7.394     101.1200      None        38
# 3      21.3       2.94     YES       9.268      11.2672      Lake        45
# 4      21.3       5.33      NO       8.824      11.2896      Lake        55
#
#   bus_ter     parks  Sold
# 0     YES  0.049347     0
# ...

# %%
# Display the information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   resid_area   506 non-null    float64
#  2   air_qual     506 non-null    float64
#  3   room_num     506 non-null    float64
#  4   age          506 non-null    float64
#  5   dist1        506 non-null    float64
#  6   dist2        506 non-null    float64
#  7   dist3        506 non-null    float64
#  8   dist4        506 non-null    float64
#  9   teachers     506 non-null    float64
#  10  poor_prop    506 non-null    float64
#  11  airport      506 non-null    object
#  12  n_hos_beds   498 non-null    float64
#  13  n_hot_rooms  506 non-null    float64
#  14  waterbody    506 non-null    object
#  15  rainfall     506 non-null    int64
#  16  bus_ter      506 non-null    object
#  17  parks        506 non-null    float64
# ...

# %%
# Display the shape of the data
df.shape
# Out:
# (506, 19)

# %%
# Display the columns of the data
df.columns
# Out:
# Index(['price', 'resid_area', 'air_qual', 'room_num', 'age', 'dist1', 'dist2',
#        'dist3', 'dist4', 'teachers', 'poor_prop', 'airport', 'n_hos_beds',
#        'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter', 'parks', 'Sold'],
#       dtype='object')

# %%
# Display the count, mean, std, minimum, Q1, Q2, Q3, and maximum
df.describe().T
# Out:
#              count       mean        std        min        25%        50%  \
# price        506.0  22.528854   9.182176   5.000000  17.025000  21.200000
# resid_area   506.0  41.136779   6.860353  30.460000  35.190000  39.690000
# air_qual     506.0   0.554695   0.115878   0.385000   0.449000   0.538000
# room_num     506.0   6.284634   0.702617   3.561000   5.885500   6.208500
# age          506.0  68.574901  28.148861   2.900000  45.025000  77.500000
# dist1        506.0   3.971996   2.108532   1.130000   2.270000   3.385000
# dist2        506.0   3.628775   2.108580   0.920000   1.940000   3.010000
# dist3        506.0   3.960672   2.119797   1.150000   2.232500   3.375000
# dist4        506.0   3.618972   2.099203   0.730000   1.940000   3.070000
# teachers     506.0  21.544466   2.164946  18.000000  19.800000  20.950000
# poor_prop    506.0  12.653063   7.141062   1.730000   6.950000  11.360000
# n_hos_beds   498.0   7.899767   1.476683   5.268000   6.634500   7.999000
# ...

# %%
# Display the histograms of all the numerical data in the dataset
df.hist(figsize=(12, 10))
plt.suptitle('Histograms for Numerical Columns', y=1.02, fontsize=16)
plt.show()

# %%
df.columns
# Out:
# Index(['price', 'resid_area', 'air_qual', 'room_num', 'age', 'dist1', 'dist2',
#        'dist3', 'dist4', 'teachers', 'poor_prop', 'airport', 'n_hos_beds',
#        'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter', 'parks', 'Sold'],
#       dtype='object')

# %%
df1 = df.groupby('airport')['price'].sum().reset_index().sort_values(by='price', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='airport', y='price', data=df1, color='green')
plt.xlabel('airport')
plt.ylabel('price')
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# **Inference**
# - The price of the resedentail area near airport are very high
# - The price of the residentail area not near airport are very low

# %%
df1 = df.groupby('waterbody')['price'].sum().reset_index().sort_values(by='price', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='waterbody', y='price', data=df1, color='green')
plt.xlabel('waterbody')
plt.ylabel('price')
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# **Inference**
# - The price of the resedentail area near river are very high
# - The price of the residentail area near lake are very low

# %%
df1 = df.groupby('airport')['age'].mean().reset_index().sort_values(by='age', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='airport', y='age', data=df1, color='blue')
plt.xlabel('airport')
plt.ylabel('age')
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# **Infernce**
# - The average age of the residenital near airport and not nearairport are almost same

# %%
df1 = df.groupby('waterbody')['age'].mean().reset_index().sort_values(by='age', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='waterbody', y='age', data=df1, color='blue')
plt.xlabel('waterbody')
plt.ylabel('age')
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# **Inference**
# - The average age of the resedentail area near none are very high
# - The average age of the residentail area near river are very low

# %%
df1 = df.groupby('airport')['Sold'].count().reset_index().sort_values(by='Sold', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='airport', y='Sold', data=df1, color='pink')
plt.xlabel('airport')
plt.ylabel('Sold')
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# **Inference**
# - The number of counts of the resedentail area near airport are very high
# - The number of counts of the residentail area not near airport are very low

# %%
df1 = df.groupby('waterbody')['Sold'].count().reset_index().sort_values(by='Sold', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='waterbody', y='Sold', data=df1, color='pink')
plt.xlabel('waterbody')
plt.ylabel('Sold')
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# **Inference**
# - The number of counts of the resedentail area near river are very high
# - The number of counts of the residentail area near lake are very low

# %% [markdown]
# ### 4. Summarize the key findings from your univariate and bivariate analyses. Discuss any trends, patterns, or insights that you discovered in the data (Perform using  Q2 and 3). (10 Marks)

# %% [markdown]
# Optional

# %% [markdown]
# ### 5. Perform the following Tasks (10 Marks)
# - Create Series using the Dictionary WITH EXPLAINATION HOW YOU PERFROM THIS.
# - Create Dataframe Using Dictionary WITH EXPLAINATION HOW YOU PERFROM THIS.
# - Perform Concatination on two dataframe (Create 2 sample tables with 2 columns nad 2 columns each) Horizontal & Verticle concatination.

# %%
# CODE HERE

# %%
import pandas as pd

# %%
players_series = pd.Series(['Virat Kohli', 'Rohit Sharma', 'KL Rahul', 'Hardik Pandya', 'Shreyas Iyer'])
score_series = pd.Series([100,90,80,70,60])

# %%
score_series
# Out:
# 0    100
# 1     90
# 2     80
# 3     70
# 4     60
# dtype: int64

# %%
# Create a DataFrame using the Series objects
df1 = pd.DataFrame({
    "Name": players_series,
    "Score": score_series
})

df1
# Out:
#             Name  Score
# 0    Virat Kohli    100
# 1   Rohit Sharma     90
# 2       KL Rahul     80
# 3  Hardik Pandya     70
# 4   Shreyas Iyer     60

# %% [markdown]
# ### Concat

# %%
# Step 1 :- Create two dataframes

import numpy as np
import pandas as pd

# First Dataframe
df_1 = pd.DataFrame(
    {
        "Name":["Ram","Shyam","Ham","Mahesh","Dan",np.nan],
        "Marks":[15,20,15,20,18,17],
        "Branch":["Mobile","NS","Fintech","BIA","Data","Game"],
    }
)

# Second Dataframe
df_2 = pd.DataFrame(
    {
        "Name":["Virat","Rohit","Ashwin",np.nan,np.nan,"Aayush"],
        "Marks":[20,22,18,np.nan,22,14],
        "Branch":["Data","Game","Mobile","NS","Fintech","BIA"],
    }
)

# %%
# Show the First Dataframes :

df_1.head()
# Out:
#      Name  Marks   Branch
# 0     Ram     15   Mobile
# 1   Shyam     20       NS
# 2     Ham     15  Fintech
# 3  Mahesh     20      BIA
# 4     Dan     18     Data

# %%
# Show the Second Dataframes :

df_2.head()
# Out:
#      Name  Marks   Branch
# 0   Virat   20.0     Data
# 1   Rohit   22.0     Game
# 2  Ashwin   18.0   Mobile
# 3     NaN    NaN       NS
# 4     NaN   22.0  Fintech

# %%
# Concatinate both the dataframes

df_concat = pd.concat([df_1,df_2])
df_concat
# Out:
#      Name  Marks   Branch
# 0     Ram   15.0   Mobile
# 1   Shyam   20.0       NS
# 2     Ham   15.0  Fintech
# 3  Mahesh   20.0      BIA
# 4     Dan   18.0     Data
# 5     NaN   17.0     Game
# 0   Virat   20.0     Data
# 1   Rohit   22.0     Game
# 2  Ashwin   18.0   Mobile
# 3     NaN    NaN       NS
# 4     NaN   22.0  Fintech
# 5  Aayush   14.0      BIA

# %%
# Column Wise Cocatination
# Concatinate both the dataframes

df_concat = pd.concat([df_1,df_2],axis = 1)
df_concat
# Out:
#      Name  Marks   Branch    Name  Marks   Branch
# 0     Ram     15   Mobile   Virat   20.0     Data
# 1   Shyam     20       NS   Rohit   22.0     Game
# 2     Ham     15  Fintech  Ashwin   18.0   Mobile
# 3  Mahesh     20      BIA     NaN    NaN       NS
# 4     Dan     18     Data     NaN   22.0  Fintech
# 5     NaN     17     Game  Aayush   14.0      BIA

# %%
# Column Wise Cocatination
# Concatinate both the dataframes

df_concat = pd.concat([df_1,df_2],axis = 0,ignore_index=True)
df_concat
# Out:
#       Name  Marks   Branch
# 0      Ram   15.0   Mobile
# 1    Shyam   20.0       NS
# 2      Ham   15.0  Fintech
# 3   Mahesh   20.0      BIA
# 4      Dan   18.0     Data
# 5      NaN   17.0     Game
# 6    Virat   20.0     Data
# 7    Rohit   22.0     Game
# 8   Ashwin   18.0   Mobile
# 9      NaN    NaN       NS
# 10     NaN   22.0  Fintech
# 11  Aayush   14.0      BIA

# %% [markdown]
# # This is the copyright of :- 50071_PatelNisarg_DAPL_DATASEM5
